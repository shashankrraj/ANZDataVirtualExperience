# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
# Import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
import numpy as np
import pandas as pd

# %%
#dataset import
df = pd.read_excel("/content/ANZ synthesised transaction dataset (1).xlsx")
df.head()
# Out:
#        status  card_present_flag  ... merchant_long_lat movement
# 0  authorized                1.0  ...     153.38 -27.99    debit
# 1  authorized                0.0  ...     151.21 -33.87    debit
# 2  authorized                1.0  ...     151.21 -33.87    debit
# 3  authorized                1.0  ...     153.05 -26.68    debit
# 4  authorized                1.0  ...     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
print(df.shape)
# Out:
# (12043, 23)

# %%
df.describe()
# Out:
#        card_present_flag  merchant_code  ...           age        amount
# count        7717.000000          883.0  ...  12043.000000  12043.000000
# mean            0.802644            0.0  ...     30.582330    187.933588
# std             0.398029            0.0  ...     10.046343    592.599934
# min             0.000000            0.0  ...     18.000000      0.100000
# 25%             1.000000            0.0  ...     22.000000     16.000000
# 50%             1.000000            0.0  ...     28.000000     29.000000
# 75%             1.000000            0.0  ...     38.000000     53.655000
# max             1.000000            0.0  ...     78.000000   8835.980000
#
# [8 rows x 5 columns]

# %%
#Required Columns
df = df[['balance','age','amount','txn_description']]

# %%
df_salary = df[df['txn_description']=='PAY/SALARY']
df_salary.head()
# Out:
#     balance  age   amount txn_description
# 50  8342.11   23  3903.95      PAY/SALARY
# 61  2040.58   23  1626.48      PAY/SALARY
# 64  3158.51   22   983.36      PAY/SALARY
# 68  2517.66   24  1408.08      PAY/SALARY
# 70  2271.79   43  1068.04      PAY/SALARY

# %%
df_salary = df_salary[['balance', 'age', 'amount']]
target_column = ['amount'] 
predictors = list(set(list(df_salary.columns))-set(target_column))
#df[predictors] = df[predictors]/df[predictors].max()
df_salary[predictors]
# Out:
#        age   balance
# 50      23   8342.11
# 61      23   2040.58
# 64      22   3158.51
# 68      24   2517.66
# 70      43   2271.79
# ...    ...       ...
# 11995   26   9378.51
# 12000   30   3440.01
# 12001   69  11381.44
# 12003   20  11454.52
# 12004   19  19893.45
#
# [883 rows x 2 columns]

# %%
X = df_salary[predictors].values
y = df_salary[target_column].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
print(X_train.shape); print(X_test.shape)
# Out:
# (706, 2)
# (177, 2)

# %%
# Define model
model = Sequential()
model.add(Dense(500, input_dim=2, activation= "relu"))
model.add(Dense(100, activation= "relu"))
model.add(Dense(50, activation= "relu"))
model.add(Dense(1))
model.summary() #Print model Summary
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_13 (Dense)             (None, 500)               1500
# _________________________________________________________________
# dense_14 (Dense)             (None, 100)               50100
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                5050
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 51
# ...
# Total params: 56,701
# Trainable params: 56,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=["accuracy"])
model.fit(X_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 706/706 [==============================] - 0s 552us/step - loss: 7713232.7266 - accuracy: 0.0000e+00
# Epoch 2/500
# 706/706 [==============================] - 0s 65us/step - loss: 6362529.1530 - accuracy: 0.0000e+00
# Epoch 3/500
# 706/706 [==============================] - 0s 65us/step - loss: 3736100.2394 - accuracy: 0.0000e+00
# Epoch 4/500
# 706/706 [==============================] - 0s 61us/step - loss: 3935241.9688 - accuracy: 0.0000e+00
# Epoch 5/500
# 706/706 [==============================] - 0s 62us/step - loss: 3746537.8428 - accuracy: 0.0000e+00
# Epoch 6/500
# 706/706 [==============================] - 0s 67us/step - loss: 3771604.2346 - accuracy: 0.0000e+00
# Epoch 7/500
# 706/706 [==============================] - 0s 71us/step - loss: 3707329.5411 - accuracy: 0.0000e+00
# Epoch 8/500
# 706/706 [==============================] - 0s 62us/step - loss: 3642854.4674 - accuracy: 0.0000e+00
# Epoch 9/500
# ...

# %%
pred_train= model.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train)))

pred_test= model.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test)))
# Out:
# 1277.8138249858378
# 1328.402755136124

# %% [markdown]
# **USING SIMPLE LR WITH AGE**

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_excel("/content/ANZ synthesised transaction dataset (1).xlsx")
df.head()
# Out:
#        status  card_present_flag  ... merchant_long_lat movement
# 0  authorized                1.0  ...     153.38 -27.99    debit
# 1  authorized                0.0  ...     151.21 -33.87    debit
# 2  authorized                1.0  ...     151.21 -33.87    debit
# 3  authorized                1.0  ...     153.05 -26.68    debit
# 4  authorized                1.0  ...     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
df_salary = df[df['txn_description']=='PAY/SALARY']
df_salary.head()
# Out:
#     status  card_present_flag  ... merchant_long_lat movement
# 50  posted                NaN  ...               NaN   credit
# 61  posted                NaN  ...               NaN   credit
# 64  posted                NaN  ...               NaN   credit
# 68  posted                NaN  ...               NaN   credit
# 70  posted                NaN  ...               NaN   credit
#
# [5 rows x 23 columns]

# %%
df_salary.plot(x='age', y='amount', style='o')  
plt.title('Age vs Amount')  
plt.xlabel('Age')  
plt.ylabel('Amount')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(df_salary['age'])

# %%
X = df_salary['age'].values.reshape(-1,1)
y = df_salary['amount'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm/
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# [2281.73938042]
# [[-11.97011741]]

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#       Actual    Predicted
# 0    2538.68  1946.576093
# 1     920.71  1970.516328
# 2    1002.13  1826.874919
# 3     920.71  1970.516328
# 4    3578.65  2030.366915
# ..       ...          ...
# 172   920.71  1970.516328
# 173  2179.96  1731.113979
# 174  3903.73  1874.755388
# 175  2687.85  1982.486445
# 176  1396.23  1958.546210
#
# [177 rows x 2 columns]

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 799.7037058736722
# Mean Squared Error: 1067082.396894937
# Root Mean Squared Error: 1032.9968039132245

# %% [markdown]
# **SIMPLE LR WITH BALANCE**

# %%
df_salary.plot(x='balance', y='amount', style='o')  
plt.title('Balance vs Amount')  
plt.xlabel('Balance')  
plt.ylabel('Amount')  
plt.show()

# %%
X = df_salary['balance'].values.reshape(-1,1)
y = df_salary['amount'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#To retrieve the intercept:
print(regressor.intercept_)
#For retrieving the slope:
print(regressor.coef_)
# Out:
# [1700.9343866]
# [[0.01183085]]

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
df
# Out:
#       Actual    Predicted
# 0    2538.68  1862.354678
# 1     920.71  1824.499968
# 2    1002.13  1727.494891
# 3     920.71  1780.908594
# 4    3578.65  1848.827635
# ..       ...          ...
# 172   920.71  1797.180988
# 173  2179.96  4825.508152
# 174  3903.73  1928.085011
# 175  2687.85  1766.513166
# 176  1396.23  1762.528889
#
# [177 rows x 2 columns]

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 801.3740990702768
# Mean Squared Error: 1109153.9882359875
# Root Mean Squared Error: 1053.1637993379697

# %% [markdown]
# **Decision Trees**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image
from subprocess import check_call

# %%
df = pd.read_excel("/content/ANZ synthesised transaction dataset (1).xlsx")
df.head()
# Out:
#        status  card_present_flag  ... merchant_long_lat movement
# 0  authorized                1.0  ...     153.38 -27.99    debit
# 1  authorized                0.0  ...     151.21 -33.87    debit
# 2  authorized                1.0  ...     151.21 -33.87    debit
# 3  authorized                1.0  ...     153.05 -26.68    debit
# 4  authorized                1.0  ...     153.44 -28.06    debit
#
# [5 rows x 23 columns]

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-d8638ba7983b> in <module>()
#       1 dt = DecisionTreeClassifier()
# ----> 2 dt.fit(X_train, y_train)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# /usr/local/lib/python3.6/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     171
#     172         if is_classification:
# --> 173             check_classification_targets(y)
#     174             y = np.copy(y)
#     175
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
# ...

# %% [markdown]
# #need to work on splitting continuous var using std dev
